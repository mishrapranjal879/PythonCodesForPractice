# %%
import torch

# %%
torch.tensor([1,2,3,4,5])
# Out:
# tensor([1, 2, 3, 4, 5])

# %%
x=torch.tensor([[1,2,3],[4,5,6]])

# %%
x.to(torch.float32)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %%
x=torch.rand(2,2)
x
# Out:
# tensor([[0.3541, 0.6475],
#         [0.8872, 0.3846]])

# %%
x+2
# Out:
# tensor([[2.3541, 2.6475],
#         [2.8872, 2.3846]])

# %%
x-2
# Out:
# tensor([[-1.6459, -1.3525],
#         [-1.1128, -1.6154]])

# %%
x*3
# Out:
# tensor([[1.0622, 1.9425],
#         [2.6617, 1.1539]])

# %%
x/3
# Out:
# tensor([[0.1180, 0.2158],
#         [0.2957, 0.1282]])

# %%
(x*100)//3
# Out:
# tensor([[11., 21.],
#         [29., 12.]])

# %%
((x*100)//3)%2
# Out:
# tensor([[1., 1.],
#         [1., 0.]])

# %%
y=torch.tensor([[10,20,30],[40,50,60]])
y
# Out:
# tensor([[10, 20, 30],
#         [40, 50, 60]])

# %%
z=torch.tensor([[2,2,7],[8,6,7]])
z
# Out:
# tensor([[2, 2, 7],
#         [8, 6, 7]])

# %%
y+z
# Out:
# tensor([[12, 22, 37],
#         [48, 56, 67]])

# %%
y-z
# Out:
# tensor([[ 8, 18, 23],
#         [32, 44, 53]])

# %%
torch.neg(y)
# Out:
# tensor([[-10, -20, -30],
#         [-40, -50, -60]])

# %%
torch.round(x)
# Out:
# tensor([[0., 1.],
#         [1., 0.]])

# %%
d=torch.tensor([1.9,2.3,3.7,4.4])
d
# Out:
# tensor([1.9000, 2.3000, 3.7000, 4.4000])

# %%
torch.floor(d)
# Out:
# tensor([1., 2., 3., 4.])

# %%
torch.clamp(d, min=2, max=3)
# Out:
# tensor([2.0000, 2.3000, 3.0000, 3.0000])

# %%
e=torch.randint(size=(2,3), low=0, high=10, dtype=torch.float32)
e
# Out:
# tensor([[3., 7., 2.],
#         [0., 2., 2.]])

# %%
f=torch.randint(size=(2,3), low=0, high=10)
g=torch.randint(size=(3,2), low=0, high=10)

print(f)
print(g)
# Out:
# tensor([[7, 0, 7],
#         [7, 6, 1]])
# tensor([[3, 1],
#         [5, 7],
#         [6, 4]])

# %%
torch.matmul(f,g)
# Out:
# tensor([[63, 35],
#         [57, 53]])
